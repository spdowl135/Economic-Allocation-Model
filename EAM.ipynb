# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('summary.csv')
df.head()
# Out:
#         Date  S&P 500 Price  3 Month T Bill        VIX  VIX MA3  VIX Adj  \
# 0   4/5/1992         401.55            4.01  16.020000    16.02        0
# 1  4/12/1992         404.29            3.80  16.719999    16.37        0
# 2  4/19/1992         416.04            3.63  16.850000    16.53        0
# 3  4/26/1992         409.02            3.68  14.850000    16.14        0
# 4   5/3/1992         412.53            3.69  15.710000    15.80        1
#
#    Valuation  Valuation Adj  Weekly  Weekly Adj            ...             \
# 0     207.45              3  113.78          -1            ...
# 1     208.98              3  116.49          -1            ...
# 2     209.72              3  116.36          -1            ...
# 3     208.64              3  115.95          -1            ...
# 4     209.91              3  116.30          -1            ...
#
#    Portfolio Return  All Return  S&P Price  T-Bill Price  Portfolio Price  \
# ...

# %%
df[['S&P Price','T-Bill Price', 'Portfolio Price', 'All Price']].plot(figsize=(14,7))

# %%
plt.scatter(df['MA Adj'], df['EAM'])
plt.show()

# %%
plt.scatter(df['MA Adj'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['MA Adj'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['VIX MA3'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['VIX MA3'], df['Portfolio Return'])
plt.show()

# %%
df[['LessVolVal','Total Score Vol']].plot(figsize=(14,7))

# %%
plt.scatter(df['Spending'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Spending'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Valuation'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Valuation'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Weekly'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Weekly'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Economy'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Economy'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Housing'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Housing'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Manufacturing'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Manufacturing'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Employment'], df['S&P Return'])
plt.show()

# %%
plt.scatter(df['Employment'], df['Portfolio Return'])
plt.show()

# %%
plt.scatter(df['MA Adj'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['MA Adj'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['VIX MA3'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['VIX MA3'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Spending'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Spending'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Valuation'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Valuation'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Weekly'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Weekly'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Economy'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Economy'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Housing'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Housing'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Manufacturing'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Manufacturing'], df['13 Week Portfolio Return'])
plt.show()

# %%
plt.scatter(df['Employment'], df['13 Week Return'])
plt.show()

# %%
plt.scatter(df['Employment'], df['13 Week Portfolio Return'])
plt.show()
